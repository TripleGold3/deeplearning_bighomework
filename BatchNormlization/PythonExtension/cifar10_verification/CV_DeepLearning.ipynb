# %%
# !nvidia-smi
# Out:
# Thu Apr 13 21:55:26 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 531.14                 Driver Version: 531.14       CUDA Version: 12.1     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                      TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf            Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 4060 L...  WDDM | 00000000:01:00.0  On |                  N/A |
# | N/A   50C    P8                6W /  N/A|   1479MiB /  8188MiB |     43%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      2084    C+G   ...Web\936\extracted\WechatBrowser.exe    N/A      |
# |    0   N/A  N/A      3272    C+G   ...on\112.0.1722.34\msedgewebview2.exe    N/A      |
# |    0   N/A  N/A      6976    C+G   ...GeForce Experience\NVIDIA Share.exe    N/A      |
# |    0   N/A  N/A      7456    C+G   ...les\Microsoft OneDrive\OneDrive.exe    N/A      |
# |    0   N/A  N/A      9644    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe    N/A      |
# |    0   N/A  N/A     13604    C+G   C:\Windows\explorer.exe                   N/A      |
# |    0   N/A  N/A     14544    C+G   ...5n1h2txyewy\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A     15120    C+G   D:\Microsoft VS Code\Code.exe             N/A      |
# |    0   N/A  N/A     16652    C+G   ...2txyewy\StartMenuExperienceHost.exe    N/A      |
# |    0   N/A  N/A     19092    C+G   ...t.LockApp_cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A     19312    C+G   ...am Files\Logi\LogiBolt\LogiBolt.exe    N/A      |
# |    0   N/A  N/A     19612    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     21780    C+G   ...tionsPlus\logioptionsplus_agent.exe    N/A      |
# |    0   N/A  N/A     22292    C+G   ...crosoft\Edge\Application\msedge.exe    N/A      |
# |    0   N/A  N/A     24004    C+G   ...siveControlPanel\SystemSettings.exe    N/A      |
# +---------------------------------------------------------------------------------------+

# %%
# !ls
# !mkdir parm
# Out:
# 'ls' �����ڲ����ⲿ���Ҳ���ǿ����еĳ���
# ���������ļ���
# ��Ŀ¼���ļ� parm �Ѿ����ڡ�

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import os

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# device = torch.device('cpu')
# Assuming that we are on a CUDA machine, this should print a CUDA device:

print(device)
# Out:
# cuda:0

# %%
batch_size = 64
LR = 0.01
num_epochs = 80
dropout = 0.5

# %%
import sys 
print(sys.path)
sys.path.append(os.getcwd() + '\\..')
print(sys.path)
# Out:
# ['e:\\Desktop\\study\\deep_learning\\BatchNormlization\\PythonExtension\\cifar10_verification', 'd:\\Anaconda\\envs\\unidl\\python39.zip', 'd:\\Anaconda\\envs\\unidl\\DLLs', 'd:\\Anaconda\\envs\\unidl\\lib', 'd:\\Anaconda\\envs\\unidl', '', 'd:\\Anaconda\\envs\\unidl\\lib\\site-packages', 'd:\\Anaconda\\envs\\unidl\\lib\\site-packages\\lltm_cpp-0.0.1-py3.9-win-amd64.egg', 'd:\\Anaconda\\envs\\unidl\\lib\\site-packages\\lltm_cuda-0.0.0-py3.9-win-amd64.egg', 'd:\\Anaconda\\envs\\unidl\\lib\\site-packages\\win32', 'd:\\Anaconda\\envs\\unidl\\lib\\site-packages\\win32\\lib', 'd:\\Anaconda\\envs\\unidl\\lib\\site-packages\\Pythonwin']
# ['e:\\Desktop\\study\\deep_learning\\BatchNormlization\\PythonExtension\\cifar10_verification', 'd:\\Anaconda\\envs\\unidl\\python39.zip', 'd:\\Anaconda\\envs\\unidl\\DLLs', 'd:\\Anaconda\\envs\\unidl\\lib', 'd:\\Anaconda\\envs\\unidl', '', 'd:\\Anaconda\\envs\\unidl\\lib\\site-packages', 'd:\\Anaconda\\envs\\unidl\\lib\\site-packages\\lltm_cpp-0.0.1-py3.9-win-amd64.egg', 'd:\\Anaconda\\envs\\unidl\\lib\\site-packages\\lltm_cuda-0.0.0-py3.9-win-amd64.egg', 'd:\\Anaconda\\envs\\unidl\\lib\\site-packages\\win32', 'd:\\Anaconda\\envs\\unidl\\lib\\site-packages\\win32\\lib', 'd:\\Anaconda\\envs\\unidl\\lib\\site-packages\\Pythonwin', 'e:\\Desktop\\study\\deep_learning\\BatchNormlization\\PythonExtension\\cifar10_verification\\..']

# %%
from MyBatchNormalization2D import MyBatchNormalization2d
from MyBatchNormalization1D import MyBatchNormalization1d
import torch.nn as nn
class Net_use_MyBn(nn.Module):
    def __init__(self):
        super().__init__()
        self.features = nn.Sequential(
            #conv1 1/2
            nn.Conv2d(in_channels=3    , out_channels=64   , kernel_size=3,  padding = 1),
            MyBatchNormalization2d(num_features=64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            #conv2 1/4 
            nn.Conv2d(in_channels=64   , out_channels=128, kernel_size=3,  padding = 1),
            MyBatchNormalization2d(num_features=128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            #conv3 1/8 
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3,  padding = 1),
            MyBatchNormalization2d(num_features=256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            #conv4 1/16 
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3,  padding = 1),
            MyBatchNormalization2d(num_features=512),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            
             #conv5 1/32 
            nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=3,  padding = 1),
            MyBatchNormalization2d(num_features=1024),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),    
        )
    
        self.classifier = nn.Sequential(  # 定义自己的分类层
            nn.Dropout(),
            nn.Linear(in_features=1024, out_features=512), 
            MyBatchNormalization1d(512),
            nn.ReLU(True),
            nn.Linear(in_features=512, out_features=256),
            MyBatchNormalization1d(256),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(in_features=256, out_features=10),
        )
    

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)

        return x

net3 = Net_use_MyBn()
net3.to(device)
# Out:
# Net_use_MyBn(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): MyBatchNormalization2d()
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): MyBatchNormalization2d()
#     (6): ReLU(inplace=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): MyBatchNormalization2d()
#     (10): ReLU(inplace=True)
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): MyBatchNormalization2d()
#     (14): ReLU(inplace=True)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (16): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): MyBatchNormalization2d()
#     (18): ReLU(inplace=True)
#     (19): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=1024, out_features=512, bias=True)
#     (2): MyBatchNormalization1d()
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=512, out_features=256, bias=True)
#     (5): MyBatchNormalization1d()
#     (6): ReLU(inplace=True)
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=256, out_features=10, bias=True)
#   )
# )

# %%
import torch.optim as optim
import torch.nn as nn
import time
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

def train_and_valid_MyBN(model, loss_function, optimizer, epochs):
    model.to(device)
    history = []
    best_acc = 0.0
    best_epoch = 0

    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch + 1, epochs))

        model.train()

        train_loss = 0.0
        train_acc = 0.0
        valid_loss = 0.0
        valid_acc = 0.0

        for i, (inputs, labels) in enumerate(train_data):
            inputs = inputs.to(device)
            labels = labels.to(device)

            # 因为这里梯度是累加的，所以每次记得清零
            optimizer.zero_grad()

            outputs = model(inputs)

            loss = loss_function(outputs, labels)

            loss.backward(retain_graph=True)

            optimizer.step()

            train_loss += loss.item() * inputs.size(0)

            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))

            acc = torch.mean(correct_counts.type(torch.FloatTensor))

            train_acc += acc.item() * inputs.size(0)

        with torch.no_grad():
            model.eval()

            for j, (inputs, labels) in enumerate(valid_data):
                inputs = inputs.to(device)
                labels = labels.to(device)

                outputs = model(inputs)

                loss = loss_function(outputs, labels)

                valid_loss += loss.item() * inputs.size(0)

                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))

                acc = torch.mean(correct_counts.type(torch.FloatTensor))

                valid_acc += acc.item() * inputs.size(0)
      

        avg_train_loss = train_loss / train_data_size
        avg_train_acc = train_acc / train_data_size

        avg_valid_loss = valid_loss / valid_data_size
        avg_valid_acc = valid_acc / valid_data_size

        history.append([avg_train_loss, avg_valid_loss, avg_train_acc, avg_valid_acc])

        if best_acc < avg_valid_acc:
            best_acc = avg_valid_acc
            best_epoch = epoch + 1

        epoch_end = time.time()

        print(
            "\t Training: Loss: {:.4f}, Accuracy: {:.4f}%, "
            "\n\t Validation: Loss: {:.4f}, Accuracy: {:.4f}%, Time: {:.3f}s".format(
                avg_train_loss, avg_train_acc * 100, avg_valid_loss, avg_valid_acc * 100,
                                epoch_end - epoch_start
            ))
        print("\t Best Accuracy for validation : {:.4f} at epoch {:03d}".format(best_acc, best_epoch))
        
        dir_path = os.path.join(os.getcwd(), ('parm/torchBN_batchsize_' + str(batch_size) + '_LR_' + str(LR) ) )
        if not os.path.exists(dir_path):
            os.mkdir(dir_path)
        model_path = dir_path + '/%02d' % (epoch + 1) + '.pt'
        torch.save(model, model_path)  # 保存模型
    
    print('Finished Training')

    return model, history

loss_func = nn.CrossEntropyLoss()
optimizer = optim.SGD(net3.parameters(), lr= LR, momentum=0.9)


all_start = time.time()

norm_mean = [0.485, 0.456, 0.406]  # 均值
norm_std = [0.229, 0.224, 0.225]  # 方差
transform_train = transforms.Compose([transforms.ToTensor(),  # 将PILImage转换为张量
                                      # 将[0,1]归一化到[-1,1]
                                      transforms.Normalize(norm_mean, norm_std),
                                      transforms.RandomHorizontalFlip(),  # 随机水平镜像
                                      transforms.RandomErasing(scale=(0.04, 0.2), ratio=(0.5, 2)),  # 随机遮挡
                                      transforms.RandomCrop(32, padding=4)  # 随机中心裁剪
                                      ])

transform_test = transforms.Compose([transforms.ToTensor(),
                                     transforms.Normalize(norm_mean, norm_std)])
  # 

# 选择数据集:
trainset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
testset = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
# 加载数据:
train_data = DataLoader(dataset=trainset, batch_size=batch_size, shuffle=True)
valid_data = DataLoader(dataset=testset, batch_size=batch_size, shuffle=False)
cifar10_classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

train_data_size = len(trainset)
valid_data_size = len(testset)
print(train_data_size, valid_data_size)

print("MyBN:")
print('Batch_Size = ' + str(batch_size) + ', Learning_Rate = ' + str(LR) + ', Train_Epochs = ' + str(num_epochs))
net3.to(device)

net3, history = train_and_valid_MyBN(model=net3, loss_function=loss_func, optimizer=optimizer, epochs=num_epochs )
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 50000 10000
# MyBN:
# Batch_Size = 64, Learning_Rate = 0.01, Train_Epochs = 80
# Epoch: 1/80
# 	 Training: Loss: 1.5489, Accuracy: 43.2020%,
# 	 Validation: Loss: 2.1651, Accuracy: 17.9400%, Time: 22.389s
# 	 Best Accuracy for validation : 0.1794 at epoch 001
# Epoch: 2/80
# 	 Training: Loss: 1.1961, Accuracy: 57.3840%,
# 	 Validation: Loss: 2.4129, Accuracy: 15.1600%, Time: 19.960s
# 	 Best Accuracy for validation : 0.1794 at epoch 001
# Epoch: 3/80
# 	 Training: Loss: 1.0397, Accuracy: 63.2760%,
# 	 Validation: Loss: 2.2985, Accuracy: 18.5100%, Time: 19.918s
# 	 Best Accuracy for validation : 0.1851 at epoch 003
# Epoch: 4/80
# 	 Training: Loss: 0.9354, Accuracy: 66.9540%,
# 	 Validation: Loss: 3.0003, Accuracy: 17.6600%, Time: 20.324s
# 	 Best Accuracy for validation : 0.1851 at epoch 003
# Epoch: 5/80
# 	 Training: Loss: 0.8648, Accuracy: 70.0360%,
# 	 Validation: Loss: 3.8882, Accuracy: 46.0700%, Time: 19.191s
# 	 Best Accuracy for validation : 0.4607 at epoch 020
# Epoch: 21/80
# 	 Training: Loss: 0.4899, Accuracy: 83.1400%,
# 	 Validation: Loss: 4.5355, Accuracy: 48.2900%, Time: 19.277s
# 	 Best Accuracy for validation : 0.4829 at epoch 021
# Epoch: 22/80
# 	 Training: Loss: 0.4699, Accuracy: 83.9760%,
# 	 Validation: Loss: 5.8786, Accuracy: 44.6900%, Time: 19.369s
# 	 Best Accuracy for validation : 0.4829 at epoch 021
# Epoch: 23/80
# 	 Training: Loss: 0.4629, Accuracy: 84.2700%,
# 	 Validation: Loss: 3.8698, Accuracy: 50.7400%, Time: 20.379s
# 	 Best Accuracy for validation : 0.5074 at epoch 023
# Epoch: 24/80
# 	 Training: Loss: 0.4542, Accuracy: 84.6900%,
# 	 Validation: Loss: 4.4473, Accuracy: 51.0000%, Time: 20.762s
# 	 Best Accuracy for validation : 0.5100 at epoch 024
# Epoch: 25/80
# 	 Training: Loss: 0.4419, Accuracy: 84.8900%,
# 	 Validation: Loss: 4.4554, Accuracy: 47.7700%, Time: 20.333s
# 	 Best Accuracy for validation : 0.5100 at epoch 024
# Epoch: 26/80
# 	 Training: Loss: 0.4308, Accuracy: 85.1960%,
# 	 Validation: Loss: 6.9672, Accuracy: 39.5100%, Time: 20.581s
# 	 Best Accuracy for validation : 0.5100 at epoch 024
# Epoch: 27/80
# 	 Training: Loss: 0.4254, Accuracy: 85.5140%,
# 	 Validation: Loss: 3.6593, Accuracy: 51.8100%, Time: 20.400s
# 	 Best Accuracy for validation : 0.5181 at epoch 027
# Epoch: 28/80
# 	 Training: Loss: 0.4191, Accuracy: 85.6160%,
# 	 Validation: Loss: 5.7556, Accuracy: 47.0100%, Time: 20.340s
# 	 Best Accuracy for validation : 0.5181 at epoch 027
# Epoch: 29/80
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 137
#     134 print('Batch_Size = ' + str(batch_size) + ', Learning_Rate = ' + str(LR) + ', Train_Epochs = ' + str(num_epochs))
#     135 net3.to(device)
# --> 137 net3, history = train_and_valid_MyBN(model=net3, loss_function=loss_func, optimizer=optimizer, epochs=num_epochs )
#
# Cell In[8], line 41, in train_and_valid_MyBN(model, loss_function, optimizer, epochs)
#      37 optimizer.step()
#      39 train_loss += loss.item() * inputs.size(0)
# ---> 41 ret, predictions = torch.max(outputs.data, 1)
#      42 correct_counts = predictions.eq(labels.data.view_as(predictions))
#      44 acc = torch.mean(correct_counts.type(torch.FloatTensor))
#
# KeyboardInterrupt:

# %%
import numpy as np
import matplotlib.pyplot as plt 
import os, sys
result_dir_path = os.path.join(os.getcwd(), ('result/torchBN_MyBN_batchsize_' + str(batch_size) + '_LR_' + str(LR) ) )
if not os.path.exists(result_dir_path):
    os.mkdir(result_dir_path)
history = np.array(history)
# Loss曲线
plt.figure(figsize=(10, 10))
plt.plot(history[:, 0:2])
plt.legend(['Tr Loss', 'Val Loss'])
plt.xlabel('Epoch Number')
plt.ylabel('Loss')
# 设置坐标轴刻度
plt.xticks(np.arange(0, num_epochs + 1, step=10))
plt.yticks(np.arange(0, 2.05, 0.1))
plt.grid()  # 画出网格
plt.savefig(result_dir_path + '/loss_curve1.png')

# 精度曲线
plt.figure(figsize=(10, 10))
plt.plot(history[:, 2:4])
plt.legend(['Train Accuracy', 'Val Accuracy'])
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy')
# 设置坐标轴刻度
plt.xticks(np.arange(0, num_epochs + 1, step=10))
plt.yticks(np.arange(0, 1.05, 0.05))
plt.grid()  # 画出网格
plt.savefig(result_dir_path + '/accuracy_curve1.png')
